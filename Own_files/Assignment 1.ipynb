# %% [markdown]
# ### CIVL 3140 - Assignment 1
# Name: Felix Law
#
# UID: 3035780805

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Missing Least Square Method steps

# %%
# Question 1

from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# define the data
question = np.array([1000]).reshape(-1,1)
# traffic_density
y = np.array([10,35,18,45]).reshape(-1,1)
# traffic_volume
X = np.array([500,1200,1000,1800]).reshape(-1,1)

# Checking math for Least Squared Method
# y_mean = y.mean()
# X_mean = X.mean()

# a = np.array([10,35,18,45]) @ np.array([500,1200,1000,1800]) -4 * y_mean * X_mean
# b = np.array([500,1200,1000,1800]) @ np.array([500,1200,1000,1800]) -4 * (X_mean **2)
# c = a/b
# print(c)

# d = y_mean - c* X_mean
# print(d)

plt.plot(y,X, '.', label = 'data points')

plt.xlabel('Traffic Density (veh/km)')
plt.ylabel('Traffic Volume (veh/hour)')
plt.title('Graph of Traffic Density against Traffic Volume')
plt.legend(loc = 0)

plt.grid()
plt.show()

# Building the Linear Regression Model
reg = LinearRegression().fit(X, y)

y_predicted = reg.predict(X)
answer = reg.predict(question)

plt.plot(y,X, '.', label = 'data points')
plt.plot(y_predicted,X, 'g-', label = 'Linear Regression')
plt.plot(answer,question, 'r.', label = 'required answer')

plt.xlabel('Traffic Density (veh/km)')
plt.ylabel('Traffic Volume (veh/hour)')
plt.title('Graph of Traffic Density against Traffic Volume')
plt.legend(loc = 0)

plt.grid()
plt.show()

plt.show()


print('According to the graph, the coefficients from the linear regression model is: \n  intercept = %.3f \n  slope = %.3f'%(reg.intercept_[0],reg.coef_[0][0]))
print('As seen on the graph, The estimated traffic density is %.3f veh/km'% (answer[0][0]))
# Out:
# According to the graph, the coefficients from the linear regression model is:
#   intercept = -4.772
#   slope = 0.028
# As seen on the graph, The estimated traffic density is 23.470 veh/km

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part I DELETE ME

# %%
import pandas as pd

X = np.array ([[1, 50383, 4784, 28318, 28.7], [1, 11084, 1664, 33120, 42.23], [1, 51122, 16059, 61815, 36.3], [1, 25970, 5383, 181995, 40.15], [1, 29222, 2891, 23981, 31.30]])
y = np.array([3459623,3914019,8100630,13460142,2535732]).reshape(-1,1)

w = X.T@X
tmp = pd.DataFrame(w)
print('\nplease ignore the index column and index row\n X^T @ X is:\n', tmp)

print('\nDeterminant of X^T @ X is:\n', np.linalg.det(w))

w = np.linalg.inv(X.T@X)
tmp = pd.DataFrame(w)
print('\nplease ignore the index column and index row\n (X^T @ X)^(-1) is:\n', tmp)

w = np.linalg.inv(X.T@X)@X.T
tmp = pd.DataFrame(w)
print('\nplease ignore the index column and index row\n (X^T @ X)^(-1) @ X^T is:\n', tmp)

w = np.linalg.inv(X.T@X)@X.T @ y
tmp = pd.DataFrame(w)
print('\nplease ignore the index column and index row\n (X^T @ X)^(-1) @ X^T @ Y is:\n', tmp)

print(f'\nTherefore, the linear regression mdoel is: \nTotInflow = {w[0][0]} + {w[1:].flatten()[0]} * TotPop + {w[1:].flatten()[1]} * AutoOwn0 + {w[1:].flatten()[2]} * TotEmp + {w[1:].flatten()[3]} * TotRdDens')
# Out:
# please ignore the index column and index row
#  X^T @ X is:
#             0             1             2             3             4
# 0       5.00  1.677810e+05  3.078100e+04  3.292290e+05  1.786800e+02
# 1  167781.00  6.803127e+09  1.304722e+09  1.038114e+10  5.727142e+06
# 2   30781.00  1.304722e+09  3.208816e+08  2.232280e+09  1.097129e+06
# 3  329229.00  1.038114e+10  2.232280e+09  3.941721e+10  1.251297e+07
# 4     178.68  5.727142e+06  1.097129e+06  1.251297e+07  6.516465e+03
#
# Determinant of X^T @ X is:
#  7.986916780940316e+28
#
# please ignore the index column and index row
#  (X^T @ X)^(-1) is:
#              0             1             2             3         4
# 0  146.215077 -1.376969e-03  2.642816e-03  5.512012e-05 -3.349798
# 1   -0.001377  1.412803e-08 -2.785562e-08 -4.484152e-10  0.000031
# 2    0.002643 -2.785562e-08  6.275408e-08  7.552246e-10 -0.000060
# 3    0.000055 -4.484152e-10  7.552246e-10  9.055421e-11 -0.000001
# 4   -3.349798  3.089033e-05 -5.999951e-05 -1.418316e-06  0.077681
#
# please ignore the index column and index row
#  (X^T @ X)^(-1) @ X^T is:
#            0         1         2         3          4
# 0 -5.095809 -4.285980  0.072259  0.218685  10.090845
# 1  0.000075  0.000023 -0.000008 -0.000001  -0.000089
# 2 -0.000161 -0.000070  0.000095 -0.000014   0.000150
# 3 -0.000002 -0.000005 -0.000002  0.000007   0.000002
# 4  0.108782  0.126230 -0.002021 -0.009803  -0.223188
#
# please ignore the index column and index row
#  (X^T @ X)^(-1) @ X^T @ Y is:
#                0
# 0 -5.288435e+06
# 1  3.926866e+01
# 2  1.279729e+02
# 3  5.918005e+01
# 4  1.561499e+05
#
# Therefore, the linear regression mdoel is:
# TotInflow = -5288434.545500217 + 39.26866196850546 * TotPop + 127.97287239032697 * AutoOwn0 + 59.180052654147616 * TotEmp + 156149.88142738346 * TotRdDens

# %% [markdown]
# ### Part II

# %% [markdown]
# #### Matrix Product

# %%
import numpy as np

# Defining the Data
# tmp = [[1, 50383, 4784, 28318, 28.7], [1, 11084, 1664, 33120, 42.23], [1, 51122, 16059, 61815, 36.3], [1, 25970, 5383, 181995, 40.15], [1, 29222, 2891, 23981, 31.30]]
# output = tmp[::]
# for i in range(5):
#     for j in range(5):
#         output[i][j] = tmp[j][i]
# print(output)


X = np.array ([[1, 50383, 4784, 28318, 28.7], [1, 11084, 1664, 33120, 42.23], [1, 51122, 16059, 61815, 36.3], [1, 25970, 5383, 181995, 40.15], [1, 29222, 2891, 23981, 31.30]])
y = np.array([3459623,3914019,8100630,13460142,2535732]).reshape(-1,1)

w = np.linalg.inv(X.T@X)@X.T @ y


print('w1~n is', w[1:].flatten())
print('w0 is', w[0])
# ! W0 is intercept and W1 is the slope 

print(f'\nTherefore, the linear regression mdoel is: \nTotInflow = {w[0][0]} + {w[1:].flatten()[0]} * TotPop + {w[1:].flatten()[1]} * AutoOwn0 + {w[1:].flatten()[2]} * TotEmp + {w[1:].flatten()[3]} * TotRdDens')
# Out:
# w1~n is [3.92686620e+01 1.27972872e+02 5.91800527e+01 1.56149881e+05]
# w0 is [-5288434.54550022]
#
# Therefore, the linear regression mdoel is:
# TotInflow = -5288434.545500217 + 39.26866196850546 * TotPop + 127.97287239032697 * AutoOwn0 + 59.180052654147616 * TotEmp + 156149.88142738346 * TotRdDens

# %% [markdown]
# #### Sklearn Method

# %%
from sklearn.linear_model import LinearRegression

X = np.array ([[50383, 4784, 28318, 28.7], [11084, 1664, 33120, 42.23], [51122, 16059, 61815, 36.3], [25970, 5383, 181995, 40.15], [29222, 2891, 23981, 31.30]])
y = np.array([3459623,3914019,8100630,13460142,2535732]).reshape(-1,1)

reg = LinearRegression().fit(X,y)

print('w1 is', reg.coef_)
print('w0 is', reg.intercept_)

print(f'\nTherefore, the linear regression mdoel is: \nTotInflow = {reg.intercept_[0]} + {reg.coef_[0][0]} * TotPop + {reg.coef_[0][1]} * AutoOwn0 + {reg.coef_[0][2]} * TotEmp + {reg.coef_[0][3]} * TotRdDens')
# Out:
# w1 is [[3.92686620e+01 1.27972872e+02 5.91800527e+01 1.56149881e+05]]
# w0 is [-5288434.54549941]
#
# Therefore, the linear regression mdoel is:
# TotInflow = -5288434.545499413 + 39.2686619684847 * TotPop + 127.9728723903708 * AutoOwn0 + 59.18005265414766 * TotEmp + 156149.88142736928 * TotRdDens

# %% [markdown]
# ### Part III

# %%
question = [34689,9443,148355,38.9]
answer =  (reg.coef_[0] @ question + reg.intercept_)[0]

print(f'the total population near eath station is {question[0]}\nnumber of households that own 0 vehicle is {question[1]}\ntotal employment is {question[2]}\ntotal road network density for station Montgomery Street is {question[3]}')
print(f'\nAccording to the multi-variable linear regression model of: \nTotInflow = {reg.intercept_[0]} + {reg.coef_[0][0]} * TotPop + {reg.coef_[0][1]} * AutoOwn0 + {reg.coef_[0][2]} * TotEmp + {reg.coef_[0][3]} * TotRdDens')
print(f'\nThe estimated total ridership inflow is {answer} units')
# Out:
# the total population near eath station is 34689
# number of households that own 0 vehicle is 9443
# total employment is 148355
# total road network density for station Montgomery Street is 38.9
#
# According to the multi-variable linear regression model of:
# TotInflow = -5288434.545499413 + 39.2686619684847 * TotPop + 127.9728723903708 * AutoOwn0 + 59.18005265414766 * TotEmp + 156149.88142736928 * TotRdDens
#
# The estimated total ridership inflow is 12136091.002538364 units

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Missing Whole Part

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd

# Define the data
X = np.array([10,35,18,45,58,65,82,74])
y = np.array([500,1200,800,1800,1300,1000,400,800])
df = pd.DataFrame({'Traffic_Density': X, 'Traffic_Volume': y})
df = df.sort_values('Traffic_Density')
# y = df['Traffic_Density'].to_numpy()
# X = df['Traffic_Volume'].to_numpy().reshape(-1,1)

#?  Uses Traffic Density to estimate Traffic Volume

# Data Visualization
plt.plot(df['Traffic_Density'],df['Traffic_Volume'],'.', label='Traffic Data')

plt.xlabel('Traffic Density (veh/km)')
plt.ylabel('Traffic Volume (veh/hour)')
plt.title('Graph of Traffic Density against Traffic Volume')
plt.legend(loc = 0)
plt.grid()
plt.tight_layout()
plt.show()

# 2nd order regression setup
# ! Do I have to change the include_bias term into True...?
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(df['Traffic_Density'].to_numpy().reshape(-1,1))

# Regression fitting
reg = LinearRegression()
reg.fit(poly_features, df['Traffic_Volume'])
y_predicted = reg.predict(poly_features)
df['Predicted_Traffic_Volume'] = y_predicted

df = df.sort_values(['Traffic_Density'])

# make another numpy array with smaller increment to meausre the Traffic Density when Traffic Volume is 1000 veh/hr and the Traffic Volume when Traffic Density is 90 veh/km
poly = PolynomialFeatures(degree=2, include_bias=False)
traffic_density_range = np.arange(10,90.1,0.001)
poly_features = poly.fit_transform(traffic_density_range.reshape(-1,1))
y_predicted = reg.predict(poly_features)
predicted_df = pd.DataFrame({'Traffic_Density': traffic_density_range, 'Predicted_Traffic_Volume': y_predicted})

plt.plot(df['Traffic_Density'],df['Traffic_Volume'],'.', label='Traffic Data')
plt.plot(traffic_density_range,y_predicted,'.-', label='Polynomial Regression')

plt.xlabel('Traffic Density (veh/km)')
plt.ylabel('Traffic Volume (veh/hour)')
plt.title('Traffic Volume = %.2f + %.2f * Traffic Density %.2f * Traffic Density^2'%(
    reg.intercept_, reg.coef_[0], reg.coef_[1]
))
plt.legend(loc = 0)
plt.grid()
plt.tight_layout()
plt.show()

print(predicted_df)
answer1 = []
answer1.append(round(float(predicted_df.iloc[(predicted_df.query('Traffic_Density < 45')['Predicted_Traffic_Volume'] - 1000).abs().argsort()[:1]]['Traffic_Density'].values),2))
answer1.append(round(float(predicted_df.iloc[(predicted_df.query('Traffic_Density > 45')['Predicted_Traffic_Volume'] - 1000).abs().argsort()[:1]]['Traffic_Density'].values),2))
print(predicted_df.iloc[(predicted_df.query('Traffic_Density > 45')['Predicted_Traffic_Volume'] - 1000)])
print(predicted_df.iloc[(predicted_df.query('Traffic_Density > 45')['Predicted_Traffic_Volume'] - 1000).abs()])
print(predicted_df.iloc[(predicted_df.query('Traffic_Density > 45')['Predicted_Traffic_Volume'] - 1000).abs().argsort()])
print(predicted_df.iloc[(predicted_df.query('Traffic_Density > 45')['Predicted_Traffic_Volume'] - 1000).abs().argsort()[:1]])
print( f'the Traffic Density is {answer1} veh/km when Traffic Volume is 1000 veh/hr')


answer2 = predicted_df[predicted_df['Traffic_Density'] >= 89.99]['Predicted_Traffic_Volume'].values[0]
print( f'the Traffic Volume is {answer2} veh/hr when Traffic Density is 90 veh/km')
# Out:
#        Traffic_Density  Predicted_Traffic_Volume
# 0               10.000                448.292516
# 1               10.001                448.350568
# 2               10.002                448.408617
# 3               10.003                448.466665
# 4               10.004                448.524712
# ...                ...                       ...
# 80095           90.095               -185.586663
# 80096           90.096               -185.660544
# 80097           90.097               -185.734427
# 80098           90.098               -185.808311
# 80099           90.099               -185.882197
#
# [80100 rows x 2 columns]
#        Traffic_Density  Predicted_Traffic_Volume
# 471             10.471                475.452336
# 471             10.471                475.452336
# 471             10.471                475.452336
# 471             10.471                475.452336
# 471             10.471                475.452336
# ...                ...                       ...
# 78915           88.915                -99.554736
# 78915           88.915                -99.554736
# 78915           88.915                -99.554736
# 78915           88.915                -99.554736
# 78915           88.915                -99.554736
#
# [45099 rows x 2 columns]
#       Traffic_Density  Predicted_Traffic_Volume
# 471            10.471                475.452336
# 471            10.471                475.452336
# 471            10.471                475.452336
# 471            10.471                475.452336
# 471            10.471                475.452336
# ...               ...                       ...
# 1185           11.185                515.927708
# 1185           11.185                515.927708
# 1185           11.185                515.927708
# 1185           11.185                515.927708
# 1185           11.185                515.927708
#
# [45099 rows x 2 columns]
#        Traffic_Density  Predicted_Traffic_Volume
# 24162           34.162               1370.127793
# 24163           34.163               1370.146045
# 24161           34.161               1370.109540
# 24164           34.164               1370.164295
# 24160           34.160               1370.091285
# ...                ...                       ...
# 45094           55.094               1391.329787
# 45095           55.095               1391.313560
# 45096           55.096               1391.297331
# 45097           55.097               1391.281100
# 45098           55.098               1391.264867
#
# [45099 rows x 2 columns]
#        Traffic_Density  Predicted_Traffic_Volume
# 24162           34.162               1370.127793
# the Traffic Density is [21.32, 34.16] veh/km when Traffic Volume is 1000 veh/hr
# the Traffic Volume is -177.91202386135956 veh/hr when Traffic Density is 90 veh/km
